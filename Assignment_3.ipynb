# %%
import pandas as pd

# %% [markdown]
# # **Q.1 Create a dataset as follow in the table.**
#
# **Q.2 From the above table that you have created, locate row 0, 4, 7 and 8 using DataFrame.**

# %%
data = pd.read_csv("/content/Dataset - Sheet1.csv")
df = pd.DataFrame(data)
df.iloc[[0,4,7,8]]
# Out:
#    Tid Refund Marital Status Taxable Income Cheat
# 0    1    Yes         Single           125K    No
# 4    5     No       Divorced            95K   Yes
# 7    8     No         Single            85K   Yes
# 8    9     No        Married            75K    No

# %% [markdown]
# **Q.3 Navigate the DataFrame and do the following task for the table created in question 1:**
#
# **1. Select row from index 3 to 7.**

# %%
df.iloc[3:8]
# Out:
#    Tid Refund Marital Status Taxable Income Cheat
# 3    4   Yes         Married           120K    No
# 4    5     No       Divorced            95K   Yes
# 5    6     No        Married            60K    No
# 6    7    Yes       Divorced           220K    No
# 7    8     No         Single            85K   Yes

# %% [markdown]
# **2. Select row from index 4 to 8, and column 2 to 4.**

# %%
df.iloc[4:9,2:5]
# Out:
#   Marital Status Taxable Income Cheat
# 4       Divorced            95K   Yes
# 5        Married            60K    No
# 6       Divorced           220K    No
# 7         Single            85K   Yes
# 8        Married            75K    No

# %% [markdown]
# **3. Select all rows with column index 1 to 3 (include index 3 during selection).**

# %%
df.iloc[:,1:4]
# Out:
#   Refund Marital Status Taxable Income
# 0    Yes         Single           125K
# 1     No        Married           100K
# 2     No        Single             70K
# 3   Yes         Married           120K
# 4     No       Divorced            95K
# 5     No        Married            60K
# 6    Yes       Divorced           220K
# 7     No         Single            85K
# 8     No        Married            75K
# 9     No         Single            90K

# %% [markdown]
# # Q.4 Read a csv file and display its first five rows.
# Note-: Download dataset from https://www.kaggle.com/datasets/uciml/iris)

# %%
dasa = pd.read_csv("/content/Iris.csv")
df2  = pd.DataFrame(dasa)
df2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Q.5 From the csv file (uploaded in the Q.4) delete row 4, and delete column 3 Display the result.**

# %%
df2 = df2.drop('SepalWidthCm',axis = 'columns') # 2nd Column dropped
df2 = df2.drop(3) #4th row dropped
df2.head()
# Out:
#    Id  SepalLengthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1            1.4           0.2  Iris-setosa
# 1   2            4.9            1.4           0.2  Iris-setosa
# 2   3            4.7            1.3           0.2  Iris-setosa
# 4   5            5.0            1.4           0.2  Iris-setosa
# 5   6            5.4            1.7           0.4  Iris-setosa

# %% [markdown]
# # Q.6 Create a sample dataset (employees.csv) containing information about employees in a company.
#   a) Shape (number of rows and columns) of the DataFrame.

# %%
data_frame = pd.read_csv("/content/employee - Sheet1.csv")
data_frame.head()
# Out:
#    Employee_Id     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         HR   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining Date  Gender  Bonus  Rating
# 0   2020-03-15  Female   5000     4.5
# 1   2017-07-19    Male   7000     4.0
# 2   2013-06-01    Male   6000     3.8
# 3   2021-02-10  Female   4500     4.7
# 4   2010-11-25    Male   5000     4.5

# %% [markdown]
# b) Summary of the DataFrame that includes the data types and non-null counts for
# each column.

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_Id          5 non-null      int64
#  1   Name                 5 non-null      object
#  2   Department           5 non-null      object
#  3   Age                  5 non-null      int64
#  4   Salary               5 non-null      int64
#  5   Years_of_Experience  5 non-null      int64
#  6   Joining Date         5 non-null      object
#  7   Gender               5 non-null      object
#  8   Bonus                5 non-null      int64
#  9   Rating               5 non-null      float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 528.0+ bytes

# %% [markdown]
# c) Generate descriptive statistics.

# %%
data_frame.describe()
# Out:
#        Employee_Id        Age       Salary  Years_of_Experience   Bonus  \
# count     5.000000   5.000000      5.00000             5.000000     5.0
# mean    103.000000  34.000000  60000.00000             7.400000  5500.0
# std       1.581139   5.612486   7905.69415             3.847077  1000.0
# min     101.000000  28.000000  50000.00000             3.000000  4500.0
# 25%     102.000000  29.000000  55000.00000             4.000000  5000.0
# 50%     103.000000  34.000000  60000.00000             8.000000  5000.0
# 75%     104.000000  38.000000  65000.00000            10.000000  6000.0
# max     105.000000  41.000000  70000.00000            12.000000  7000.0
#
#          Rating
# count  5.000000
# mean   4.300000
# std    0.380789
# min    3.800000
# 25%    4.000000
# 50%    4.500000
# 75%    4.500000
# max    4.700000

# %% [markdown]
# d) Display the first 5 rows and last 3 rows of the dataset.

# %%
data_frame.head()
# Out:
#    Employee_Id     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         HR   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining Date  Gender  Bonus  Rating
# 0   2020-03-15  Female   5000     4.5
# 1   2017-07-19    Male   7000     4.0
# 2   2013-06-01    Male   6000     3.8
# 3   2021-02-10  Female   4500     4.7
# 4   2010-11-25    Male   5000     4.5

# %%
data_frame.tail(3)
# Out:
#    Employee_Id     Name Department  Age  Salary  Years_of_Experience  \
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining Date  Gender  Bonus  Rating
# 2   2013-06-01    Male   6000     3.8
# 3   2021-02-10  Female   4500     4.7
# 4   2010-11-25    Male   5000     4.5

# %% [markdown]
# e) Calculate the following statistics from the dataset:
#
# i. The average salary of employees.
#
# ii. The total bonus paid to all employees.
#
# iii. The youngest employee's age.
#
# iv. The highest performance rating.

# %%
salary = data_frame['Salary']
avg = 0
c = 0
for i in salary:
  c+=1
  avg += i
avg = avg/c
print(f"The Average of all the Salaries = Rs {avg}")
t = 0
for i in data_frame['Bonus']:
  t = t+i
print(f"The Sum of all bonuses = Rs {t}")
a = min(data_frame['Age'])
print(f"The age of the younges employee is {a}")
print(f"The highest performance rating is {max(data_frame['Rating'])}")
# Out:
# The Average of all the Salaries = Rs 60000.0
# The Sum of all bonuses = Rs 27500
# The age of the younges employee is 28
# The highest performance rating is 4.7

# %% [markdown]
# f) Sort the DataFrame by the Salary column in descending order.

# %%
data_frame.sort_values('Salary',ascending=False)
# Out:
#    Employee_Id     Name Department  Age  Salary  Years_of_Experience  \
# 1          102      Bob         HR   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 4          105   Edward      Sales   38   60000                   12
# 3          104    Diana  Marketing   28   55000                    3
# 0          101    Alice         HR   29   50000                    4
#
#   Joining Date  Gender  Bonus  Rating
# 1   2017-07-19    Male   7000     4.0
# 2   2013-06-01    Male   6000     3.8
# 4   2010-11-25    Male   5000     4.5
# 3   2021-02-10  Female   4500     4.7
# 0   2020-03-15  Female   5000     4.5

# %% [markdown]
# g) Add a new column that categorizes employees based on their performance rating:
#
# i. Excellent for ratings >= 4.5
#
# ii. Good for ratings >= 4.0 but < 4.5
#
# iii. Average for ratings < 4.0

# %%
rate = []
for i in data_frame['Rating']:
  if(i>=4.5):
    rate.append('Excellent')
  elif(i>=4.0 and i<4.5):
    rate.append('Good')
  else:
    rate.append('Average')

data_frame['Category'] = rate
data_frame
# Out:
#    Employee_Id     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         HR   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining Date  Gender  Bonus  Rating   Category
# 0   2020-03-15  Female   5000     4.5  Excellent
# 1   2017-07-19    Male   7000     4.0       Good
# 2   2013-06-01    Male   6000     3.8    Average
# 3   2021-02-10  Female   4500     4.7  Excellent
# 4   2010-11-25    Male   5000     4.5  Excellent

# %% [markdown]
# h) Identify missing values in the DataFrame.

# %%
data_frame.isna()
#false means not missing
#true means a value is missing
# Out:
#    Employee_Id   Name  Department    Age  Salary  Years_of_Experience  \
# 0        False  False       False  False   False                False
# 1        False  False       False  False   False                False
# 2        False  False       False  False   False                False
# 3        False  False       False  False   False                False
# 4        False  False       False  False   False                False
#
#    Joining Date  Gender  Bonus  Rating  Category
# 0         False   False  False   False     False
# 1         False   False  False   False     False
# 2         False   False  False   False     False
# 3         False   False  False   False     False
# 4         False   False  False   False     False

# %% [markdown]
# i) Rename the Employee_ID column to ID.

# %%
data_frame['Column_ID'] = data_frame.pop('Employee_Id')
data_frame
# Out:
#       Name Department  Age  Salary  Years_of_Experience Joining Date  Gender  \
# 0    Alice         HR   29   50000                    4   2020-03-15  Female
# 1      Bob         HR   34   70000                    8   2017-07-19    Male
# 2  Charlie         IT   41   65000                   10   2013-06-01    Male
# 3    Diana  Marketing   28   55000                    3   2021-02-10  Female
# 4   Edward      Sales   38   60000                   12   2010-11-25    Male
#
#    Bonus  Rating   Category  Column_ID
# 0   5000     4.5  Excellent        101
# 1   7000     4.0       Good        102
# 2   6000     3.8    Average        103
# 3   4500     4.7  Excellent        104
# 4   5000     4.5  Excellent        105

# %% [markdown]
# j) Find all employees who:
#
# i. Have more than 5 years of experience.
#
# ii. Belong to the IT department.

# %%
filter = data_frame[(data_frame['Years_of_Experience']>5) & (data_frame['Department'] == 'IT')]
filter
# Out:
#       Name Department  Age  Salary  Years_of_Experience Joining Date Gender  \
# 2  Charlie         IT   41   65000                   10   2013-06-01   Male
#
#    Bonus  Rating Category  Column_ID
# 2   6000     3.8  Average        103

# %% [markdown]
# k) Modify the dataset by adding a new column, Tax, which deducts 10% of the
# Salary.

# %%
data_frame['Tax'] = (10*data_frame['Salary'])/100
data_frame
# Out:
#       Name Department  Age  Salary  Years_of_Experience Joining Date  Gender  \
# 0    Alice         HR   29   50000                    4   2020-03-15  Female
# 1      Bob         HR   34   70000                    8   2017-07-19    Male
# 2  Charlie         IT   41   65000                   10   2013-06-01    Male
# 3    Diana  Marketing   28   55000                    3   2021-02-10  Female
# 4   Edward      Sales   38   60000                   12   2010-11-25    Male
#
#    Bonus  Rating   Category  Column_ID     Tax
# 0   5000     4.5  Excellent        101  5000.0
# 1   7000     4.0       Good        102  7000.0
# 2   6000     3.8    Average        103  6500.0
# 3   4500     4.7  Excellent        104  5500.0
# 4   5000     4.5  Excellent        105  6000.0

# %% [markdown]
# l) Save the modified DataFrame (with added columns) to a new CSV file.

# %%
data_frame.to_csv('/content/drive/MyDrive/empnew.csv',index = False)
